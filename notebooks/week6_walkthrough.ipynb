# %%
import sys,os
sys.path.append('/Users/olixstudios/Documents/workspace/Projects/llm-assistant/src')



from chain import run_analysis_chain


print(run_analysis_chain(context="", question="Summarize the task list for Week 6 in one line."))
# Out:
# No reference found. Please provide the relevant context or details for Week 6's task list.
