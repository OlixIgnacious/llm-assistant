# %%
context = "this is me doing something"
question = "what i am doing"

# %%
import sys
sys.path.append('../src')  # Add the src directory to the Python path
from prompts import render_analysis_prompt

print(render_analysis_prompt(context, question))

# %%
import os
from typing import Optional
from openai import OpenAI

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=OPENAI_API_KEY)


def call_completion(prompt: str, model: str = "gpt-4o-mini", max_tokens: int = 512, temperature: float = 0.0) -> str:
    resp = client.chat.completions.create(model=model, 
    messages=[
        {"role": "system", "content": "You are AnalystGPT"},
        {"role": "user", "content": prompt}
    ],
    max_tokens=max_tokens,
    temperature=temperature)
    return resp

# %%
call_completion("Tell me a joke", "gpt-4o-mini", 500, 0.0)
